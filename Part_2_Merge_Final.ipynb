# %%
import pandas as pd

import os

os.chdir(r"D:\dataverse_files\Sample")

# Create four sample dataframes
df1 = pd.read_csv('2005sample.csv')
df2 = pd.read_csv('2006sample.csv')
df3 = pd.read_csv('2007sample.csv')
df4 = pd.read_csv('2008sample.csv')

# Merge the dataframes using pd.concat()
merged_df = pd.concat([df1, df2, df3, df4], axis=0)

# Print the merged dataframe
print(merged_df)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0    2005      9          26          1   1000.0        1009   1122.0
# 1    2005     10          26          3   1307.0        1317   1319.0
# 2    2005      9          10          6   2114.0        2119   2159.0
# 3    2005      9          23          5   2052.0        2030   2212.0
# 4    2005      3          19          6   1852.0        1855   2400.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 995  2008      2          20          3   1840.0        1800   1932.0
# 996  2008      1           6          7    620.0         620   1132.0
# 997  2008      1           6          7   1031.0        1034   1614.0
# 998  2008      2           9          6    832.0         840   1058.0
# 999  2008      3           4          2   1955.0        1845   2037.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
merged_df
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0    2005      9          26          1   1000.0        1009   1122.0
# 1    2005     10          26          3   1307.0        1317   1319.0
# 2    2005      9          10          6   2114.0        2119   2159.0
# 3    2005      9          23          5   2052.0        2030   2212.0
# 4    2005      3          19          6   1852.0        1855   2400.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 995  2008      2          20          3   1840.0        1800   1932.0
# 996  2008      1           6          7    620.0         620   1132.0
# 997  2008      1           6          7   1031.0        1034   1614.0
# 998  2008      2           9          6    832.0         840   1058.0
# 999  2008      3           4          2   1955.0        1845   2037.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# save the DataFrame to a CSV file
merged_df.to_csv("Dataset.csv", index=False)

# %% [markdown]
# # Thank You
